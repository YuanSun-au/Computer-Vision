# %%
import numpy as np
from scipy import signal, misc, ndimage
import matplotlib.pyplot as plt
import matplotlib.image as mpimg 
from IPython.display import Image
# Image(filename='phuong huong xac dinh.PNG')

# %% [markdown]
# # Computer Vision

# %% [markdown]
# ## Lecture 2: Features and Descriptors I

# %% [markdown]
# ### Linear Diffusion

# %% [markdown]
# General Difuson equation
# \begin{align}
#     \partial_t u = div(D.\nabla u) = \nabla^T ( D.\nabla u )
# \end{align}
# For linear case $D=1$
# \begin{align}
#     \partial_t u = \nabla^T \nabla u = \Delta u
# \end{align}
# with boundary/initial coditions
# \begin{align}
#     &u(x,y,t=0) = f(x,y) \\
#     &\partial_n u =n^T \nabla u = 0
# \end{align}

# %% [markdown]
# ### Gaussian Convolution

# %% [markdown]
# Grey-scale image be represented by a bounded function $f: \Omega \rightarrow \mathbb R$, with image domain $\Omega:=(0,a_1)\times(0,a_2)$

# %% [markdown]
# #### Convolution:
# \begin{align}
#     \left(K_{\sigma} * f\right)(\boldsymbol{x}):=\int_{\mathbb{R}^{2}} K_{\sigma}(\boldsymbol{y}) f(\boldsymbol{x}-\boldsymbol{y}) d \boldsymbol{y}
# \end{align}
# Gaussian Kernel
# %\begin{align}
#    $ K_{\sigma}(\boldsymbol{x}):=\frac{1}{2 \pi \sigma^{2}} \exp \left(-\frac{|\boldsymbol{x}|^{2}}{2 \sigma^{2}}\right) $
# %\end{align}
# Analytical solution for linear diffusion is a gaussian convolution:
# \begin{align}
#     u(\boldsymbol{x}, t)=\left\{\begin{array}{ll}
#     {f(\boldsymbol{x})} & {(t=0)} \\
#     {\left(K_{\sqrt{2 t}} * f\right)(\boldsymbol{x})} & {(t>0)}
#     \end{array}\right.
# \end{align}
# Relation between diffusion time and kernel width: $t = \dfrac{1}{2}\sigma^2$

# %%
def gausConv(img,sigma=1,tau=0.1,hx=1,hy=1):
    hx = hy = 1
    tau = 0.25
    t = 0.5*sigma**2
    gaussianKernel = np.array([[0, tau/hy**2, 0],[tau/hx**2, 1-2*tau/hx**2-2*tau/hy**2, tau/hx**2],[0, tau/hy**2, 0]])
    for t in np.arange(0,t,tau):
        img = signal.convolve2d(img, gaussianKernel, boundary='symm', mode='same')
    return img

# %%
# img = mpimg.imread('./images/sbrain.pgm') 
img = misc.face(gray=True).astype(np.float32)
grad = gausConv(img, sigma=5)

# %%
fig, (ax_orig, ax_conv) = plt.subplots(1,2, figsize=(8,10))
ax_orig.imshow(img, cmap='gray')
ax_orig.set_title('Original')
ax_orig.set_axis_off()
ax_conv.imshow(np.absolute(grad), cmap='gray')
ax_conv.set_title('Gradient magnitude')
ax_conv.set_axis_off()
fig.show()

# %% [markdown]
# ### Image Pyramids

# %% [markdown]
# ### Edges

# %% [markdown]
# ### Edges

# %% [markdown]
# <img src=./images/Perona-Malik-filter.png width="400">

# %%
fig, (ax_orig, ax_mag, ax_ang) = plt.subplots(1,3, figsize=(14,10))
ax_orig.imshow(img, cmap='gray')
ax_orig.set_title('Original')
ax_orig.set_axis_off()
ax_mag.imshow(np.absolute(grad), cmap='gray')
ax_mag.set_title('Gradient magnitude')
ax_mag.set_axis_off()
ax_ang.imshow(np.angle(grad), cmap='hsv') # hsv is cyclic, like angles
ax_ang.set_title('Gradient orientation')
ax_ang.set_axis_off()
fig.show()
